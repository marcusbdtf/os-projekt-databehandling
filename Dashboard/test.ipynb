# %%
import pandas as pd
import plotly_express as px
import hashlib as hl

# %%
import pandas as pd
import hashlib as hl
"""Data"""
athletes = pd.read_csv("../Data/athlete_events.csv")
hashed_names = athletes["Name"].apply(lambda x: hl.sha256(x.encode()).hexdigest())
athletes.insert(1,"Hashed name", hashed_names)
athletes = athletes.drop(columns="Name")
athletes["Total"] = athletes["ID"]
athletes = athletes.drop_duplicates(subset=["Medal", "Games","Event"])
athletes.drop(axis=1, columns=["ID", "Hashed name", "Team"], inplace=True)
all_countries_df = athletes

italy_df = athletes[athletes["NOC"]=="ITA"]

def get_italy_data():
    return italy_df

def get_all_countries():
    return all_countries_df

def process_data(old_df, col):
    filtered_df = old_df.groupby(col).count().reset_index()
    filtered_df = filtered_df.sort_values(by="Total", ascending=False)
    filtered_df = filtered_df[[col, "Total"]].reset_index()
    return filtered_df

# %%
italy = get_italy_data()

# %%
italy = process_data(italy, "Sport")

# %%
italy
# Out:
#     index                      Sport  Total
# 0      16                    Fencing    134
# 1       3                  Athletics     82
# 2      13                    Cycling     70
# 3      27                     Rowing     59
# 4       9                     Boxing     51
# 5      29                   Shooting     47
# 6      19                 Gymnastics     46
# 7      11       Cross Country Skiing     39
# 8       0              Alpine Skiing     34
# 9      15              Equestrianism     31
# 10     36                   Swimming     29
# 11     45                  Wrestling     26
# 12     10                   Canoeing     23
# 13     28                    Sailing     19
# 14     22                       Luge     19
# 15     44              Weightlifting     18
# 16      2           Art Competitions     16
# 17     14                     Diving     16
# 18      8                  Bobsleigh     16
# 19     30  Short Track Speed Skating     16
# 20     21                       Judo     15
# 21     43                 Water Polo     14
# 22     35              Speed Skating     10
# 23     24          Modern Pentathlon      8
# 24     25            Nordic Combined      7
# 25      1                    Archery      7
# 26     33               Snowboarding      7
# 27     17             Figure Skating      6
# 28     42                 Volleyball      6
# 29     18                   Football      5
# 30     32                Ski Jumping      4
# 31      7                   Biathlon      4
# 32     38                  Taekwondo      3
# 33     26        Rhythmic Gymnastics      3
# 34      5                 Basketball      3
# 35     40               Trampolining      2
# 36     12                    Curling      2
# 37      4                  Badminton      2
# 38     34                   Softball      2
# 39     20                 Ice Hockey      2
# 40      6           Beach Volleyball      2
# 41     37      Synchronized Swimming      1
# 42     39                     Tennis      1
# 43     41                 Tug-Of-War      1
# 44     31                   Skeleton      1
# 45     23        Military Ski Patrol      1

# %%
athletes = pd.read_csv("../Data/athlete_events.csv")
hashed_names = athletes["Name"].apply(lambda x: hl.sha256(x.encode()).hexdigest())
athletes.insert(1,"Hashed name", hashed_names)
athletes = athletes.drop(columns="Name")
athletes["Total"] = athletes["ID"]
athletes = athletes.drop_duplicates(subset=["Medal", "Games","Event"])
athletes.drop(axis=1, columns=["ID", "Hashed name", "Team"], inplace=True)

all_countries_df = athletes.reset_index()
italy_df = athletes[athletes["NOC"]=="ITA"].drop(axis=1, columns="NOC").reset_index()
all_countries_df.head()
# Out:
#    index Sex   Age  Height  Weight  NOC        Games  Year  Season       City  \
# 0      0   M  24.0   180.0    80.0  CHN  1992 Summer  1992  Summer  Barcelona
# 1      1   M  23.0   170.0    60.0  CHN  2012 Summer  2012  Summer     London
# 2      2   M  24.0     NaN     NaN  DEN  1920 Summer  1920  Summer  Antwerpen
# 3      3   M  34.0     NaN     NaN  DEN  1900 Summer  1900  Summer      Paris
# 4      4   F  21.0   185.0    82.0  NED  1988 Winter  1988  Winter    Calgary
#
#            Sport                             Event Medal  Total
# 0     Basketball       Basketball Men's Basketball   NaN      1
# 1           Judo      Judo Men's Extra-Lightweight   NaN      2
# 2       Football           Football Men's Football   NaN      3
# 3     Tug-Of-War       Tug-Of-War Men's Tug-Of-War  Gold      4
# 4  Speed Skating  Speed Skating Women's 500 metres   NaN      5

# %%
italy_df.head()
px.scatter()
